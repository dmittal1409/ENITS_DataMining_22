# %% [markdown]
# <a href="https://colab.research.google.com/github/dmittal1409/ENITS_DataMining_22/blob/main/Week_4/Assignment_4.1_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment I - Matplotlib
# Use the [Big-Mart Data](https://www.kaggle.com/brijbhushannanda1979/bigmart-sales-data) for some plotting exercises

# %%
#get the data
# !git clone https://github.com/keuperj/DATA.git
# Out:
# Cloning into 'DATA'...
# remote: Enumerating objects: 101, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 101 (delta 2), reused 14 (delta 2), pack-reused 87
# Receiving objects: 100% (101/101), 146.44 MiB | 22.92 MiB/s, done.
# Resolving deltas: 100% (23/23), done.
# Checking out files: 100% (69/69), done.

# %%
#import an read big-mart data
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sc
# %matplotlib inline

data = pd.read_csv("DATA/company_sales_data.csv")

# %%
#short preview of the data table
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#access data rows by name
plt.plot(data.toothpaste)

# %% [markdown]
# ## Exercise 1
# Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
sc.barplot(x = data['month_number'],y=data['toothpaste'])

# %% [markdown]
# ## Exercise 2
# Get Total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties:
#
# * Line Style dotted and Line color should be red
# * Show legend at the lower right location.
# * X label name = Month Number
# * Y label name = Sold units number
# * Add a circle marker.
# * Line marker color as read
# * Line width should be 3

# %%
plt.xlabel("Month Number")
plt.ylabel("Sold units number")
plt.title("Total profit")
plt.plot(data['month_number'], data['total_profit'], color = 'green',
         linestyle = '--', marker = 'o', label = 'Profit data of last year',
         markerfacecolor = 'red', markersize = 12)
plt.legend()

# %% [markdown]
# ## Exercise 3
# Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product for each product).

# %%
monthList  = data ['month_number']
faceCremSalesData   = data ['facecream']
faceWashSalesData   = data ['facewash']
toothPasteSalesData = data ['toothpaste']
bathingsoapSalesData   = data ['bathingsoap']
shampooSalesData   = data ['shampoo']
moisturizerSalesData = data ['moisturizer']


plt.plot(monthList, faceCremSalesData,   label = 'Face cream', marker='o', linewidth=3)
plt.plot(monthList, faceWashSalesData,   label = 'Face Wash',  marker='o', linewidth=3)
plt.plot(monthList, toothPasteSalesData, label = 'Toothpaste ', marker='o', linewidth=3)
plt.plot(monthList, bathingsoapSalesData, label = 'Bathing Soap', marker='o', linewidth=3)
plt.plot(monthList, shampooSalesData, label = 'Shampoo', marker='o', linewidth=3)
plt.plot(monthList, moisturizerSalesData, label = 'Moisturizer', marker='o', linewidth=3)
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')

plt.legend()
plt.xticks(monthList)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.title('Sales data')
# Out:
# Text(0.5, 1.0, 'Sales data')

# %% [markdown]
# ## Exercise 4
# Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot.

# %%
plt.scatter(monthList, toothPasteSalesData, label = 'Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.legend()
plt.title(' Tooth paste Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle = 'solid', color='green')

# %% [markdown]
# ## Exercise 5
# Read face cream and facewash product sales data and show it using the bar chart
# Bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
plt.bar([a-0.25 for a in monthList], faceCremSalesData, width= 0.25, label = 'Face Cream sales data', align='edge' ,color ='yellow')
plt.bar([a+0.25 for a in monthList], faceWashSalesData, width= -0.25, label = 'Face Wash sales data', align='edge' ,color = 'pink')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.title(' Sales data')
plt.xticks(monthList)
plt.grid(True, linewidth= 1, linestyle="--")
plt.title('Facewash and facecream sales data')
# Out:
# Text(0.5, 1.0, 'Facewash and facecream sales data')

# %% [markdown]
# ## Exercise 6
# Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# ***Note:*** use ``data[item].sum()`` to compute sums over columns

# %%
data['toothpaste'].sum()
labels = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData   = [data ['facecream'].sum(), data ['facewash'].sum(), data ['toothpaste'].sum(), 
         data ['bathingsoap'].sum(), data ['shampoo'].sum(), data ['moisturizer'].sum()]

plt.axis("equal")

plt.pie(salesData, labels=labels, autopct='%1.1f%%' )
plt.legend()
plt.title('Sales data')
# Out:
# Text(0.5, 1.0, 'Sales data')
